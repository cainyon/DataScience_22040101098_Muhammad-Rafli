# %% [markdown]
# <a href="https://colab.research.google.com/github/cainyon/DataScience_22040101098_Muhammad-Rafli/blob/main/Pertemuan1_%5BMuhammad_Rafli%5D_%5B220401010198%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Nama  : Muhammad Rafli
# ### Nim   : 22040101098
# ### Kelas : IF405

# %%
# ===================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ===================================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# Variabel dan tipe data dasar
nama     = "Muhammad Rafli"   # String
angkatan = 2024                      # Integer
ipk      = 3.75                      # Float
aktif    = True                      # Boolean

print(f"Nama     : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK      : {ipk}")
print(f"Aktif    : {aktif}")
# Out:
# Nama     : Muhammad Rafli
# Angkatan : 2024
# IPK      : 3.75
# Aktif    : True

# %%
# List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %%
# Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Muhammad Rafli", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Muhammad Rafli dari Informatika, angkatan 2024.

# %% [markdown]
# #Kesimpulan dan Refleksi Pertemuan Satu
# ### Apa yang di pelajari
# Pada pertemuan ini saya telah mempelajari dasar dasar penggunaan google collab dan sintak dasar bahasa program python yang sangat penting untuk data science meliputi :
# 1. output sederhana menggunakan fungsi 'print()'
# 2. Variabel dan Tipe data seperti string, integer, float, boolean
# 3. Melakukan iterasi menggunakan perulangan 'for' di bantu fungsi 'enumerate()' untuk memberikan nomor indek
# 4. Function, membuat fungsi custom dengan 'def' untuk membungkus blok agar bisa di gunakan kembali secara efisien
#
# ###Temuan Singkat
# * Google colab sangat memudahkan belajar data science karena tidak perlu melakukan installasi python di komputer lokal serta banyak tool lainnya
